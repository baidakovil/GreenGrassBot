# %%
from urllib.request import urlopen
from datetime import datetime, timedelta
from pathlib import Path
import urllib.parse
from html import unescape

def printToTelegram(textToTelegram) :
    print(textToTelegram)
    
def prettyThree(threeIndentDict, indent=2):
    prettyList = list()
    prettyString = str()
    for key1, value1 in threeIndentDict.items():
        prettyList.append(str(key1)+'\n')
        for key2, value2 in value1.items():
            prettyList.append(' ' * indent + str(key2) + '\n')
            for k, v in value2.items() :
                prettyList.append(' ' * 2 * indent + k + ' : ' + v + '\n')
    prettyString = prettyString.join(prettyList)
    print('\n', prettyString)

def pageCacher(pageType,pageId,url) :
    htmlList = []
    if pageType == 'eventPage' :
        safeCharacters = (' ','.',',','_','-','!')
        safeArtistName = "".join([c for c in pageId if c.isalnum() or c in safeCharacters])
        cacheFileName = 'cache/concerts/' + safeArtistName + '_lastfm.html'                   
        try :         
            cacheHandle = open(cacheFileName, 'r', encoding="utf-8")
            htmlText = cacheHandle.read()
            htmlList = htmlText.splitlines()
            print( pageId + ' event page found in cache..',end='')
            cacheHandle.close()
        except FileNotFoundError:
            print('Downloading {} event page...'.format(pageId), end = '') 
    elif pageType == 'libraryPage' :
        cacheFileName = 'cache/library/{}/{}.html'.format(pageId.split('_')[0],pageId)
        try :
            cacheHandle = open(cacheFileName, 'r', encoding="utf-8")
            htmlText = cacheHandle.read()  
            htmlList = htmlText.splitlines()
            print( 'Library {} found in cache..'.format(pageId),end='')
            cacheHandle.close()
        except FileNotFoundError:
            Path('cache/library/' + pageId.split('_')[0]).mkdir(exist_ok=True)
            print('Downloading {} library page...'.format(pageId), end = '') 
    if htmlList == [] :
        htmlByte = urlopen(url).read()
        htmlText = htmlByte.decode()   
        htmlList = htmlText.splitlines()
        cacheHandle = open(cacheFileName,'w', encoding="utf-8")
        cacheHandle.write(htmlText)
        cacheHandle.close()
        print('Done')
    return htmlList

def parserLibrary(lastfmUser,timeDelay) -> 'artistList' :    
    pageNum = 0
    today = datetime.utcnow()
    artistList = dict()
    stopParsing = False 
    while not stopParsing:
        if pageNum >= 100 : 
            print('Too many pages')
            break
        pageNum += 1
        lastfmUserUrl = 'https://www.last.fm/user/'+lastfmUser+'/library?page='+str(pageNum)
        pageId = '{}_page_{}'.format(lastfmUser,pageNum)
        htmlList = pageCacher(pageType='libraryPage', pageId = pageId, url=lastfmUserUrl)    
        htmlIterator = iter(htmlList)
        line = next(htmlIterator)
        try :
            for i in range(0,50) :
                while 'class="chartlist-artist' not in line : line = next(htmlIterator)
                while 'title=' not in line : line = next(htmlIterator)
                artist = html.unescape(line.split('"')[1])
                while 'chartlist-timestamp--lang-en' not in line : line = next(htmlIterator)
                while 'span title' not in line : line = next(htmlIterator)        
                timeStr = line.split('"')[1]
                timeStrFormatted = datetime.strptime(timeStr,"%A %d %b %Y, %I:%M%p")
                if (today - timeStrFormatted) > timeDelay : 
                    stopParsing = True
                    print('Parsed. timeDelay reached')
                    break
                else :
                    artistList[artist] = artistList.get(artist,0) + 1 #сделать форматирование по регистру АБВ->Абв
        except StopIteration :
            stopParsing = True
            print('Parsed. No more tracks\n')
        print('Parsed')
    return artistList

def parserLastfmEvent(htmlList,eventArtist) :
    artistEventBasket = dict()
    htmlIterator = iter(htmlList)
    line = next(htmlIterator)  
    try :
        for i in range(0,100) :
            while 'class="events-list-item-date"' not in line : line = next(htmlIterator)
            eventTime = line.split('"')[5][:10]
            while 'class="events-list-item-venue--title"' not in line : line = next(htmlIterator)
            line = next(htmlIterator)
            eventVenue = line.strip()
            while 'class="events-list-item-venue--address"' not in line : line = next(htmlIterator)
            line = next(htmlIterator)
            eventAddress = line.strip()
            artistEventBasket[eventArtist+'-in-'+eventTime]={
                                         'eventartist':eventArtist,
                                         'eventtime':eventTime,
                                         'eventvenue':eventVenue,
                                         'eventcity':eventAddress.split(', ')[0],
                                         'eventcountry':eventAddress.split(', ')[1]}
    except StopIteration :
        if artistEventBasket == {} :
            print('No concerts from ',eventArtist)
        else :
            print('Done with ',eventArtist)
    return artistEventBasket

# %%
def getLastfmEvents(lastfmUser,hoursDelta,minListens) :
    timeDelay = timedelta(hours=hoursDelta)
    eventBasket = dict()
    provedArtistList = list()
   
    artistList = parserLibrary(lastfmUser,timeDelay)
        
    for actArtist, listens in artistList.items() :
        if listens >= minListens :
            provedArtistList.append(actArtist)
    print ('\nprovedArtistList: \n', provedArtistList)
    print ('Artist proved:',len(provedArtistList),'\n')

    for eventArtist in provedArtistList :
        lastfmEventUrl = 'https://www.last.fm/music/' + urllib.parse.quote(eventArtist,safe='') + '/+events'
        htmlList = pageCacher(pageType='eventPage', pageId = eventArtist, url=lastfmEventUrl)
        artistEventBasket = parserLastfmEvent(htmlList, eventArtist)
        if artistEventBasket != {} :
            eventBasket[eventArtist] = artistEventBasket
            artistEventBasket = {}
    return eventBasket

# %%
lastfmUser='ivanshello'
hoursDelta = 200
minListens = 3

events = getLastfmEvents(lastfmUser,hoursDelta,minListens)
prettyThree(events)
# Out:
# Library ivanshello_page_1 found in cache..Parsed
# Library ivanshello_page_2 found in cache..Parsed
# Library ivanshello_page_3 found in cache..Parsed
# Library ivanshello_page_4 found in cache..Parsed
# Library ivanshello_page_5 found in cache..Parsed. timeDelay reached
# Parsed
#
# provedArtistList:
#  ['Константин Никольский', 'Владимир Высоцкий', 'Валерий Ободзинский', 'Людмила Гурченко', 'Виа "Волга-Волга"', 'Мураками', 'Briqueville', 'Сплин', 'Воплі Відоплясова', 'Голос Омерики', 'Борис Гребенщиков', 'Чайф', '7Б', 'Мёртвые Дельфины', 'Wynton Marsalis', 'David Bowie', 'Потомучто']
# Artist proved: 17
#
# Константин Никольский event page found in cache..No concerts from  Константин Никольский
# Владимир Высоцкий event page found in cache..No concerts from  Владимир Высоцкий
# Валерий Ободзинский event page found in cache..No concerts from  Валерий Ободзинский
# Людмила Гурченко event page found in cache..No concerts from  Людмила Гурченко
# Виа "Волга-Волга" event page found in cache..No concerts from  Виа "Волга-Волга"
# Мураками event page found in cache..Done with  Мураками
# Briqueville event page found in cache..Done with  Briqueville
# Сплин event page found in cache..Done with  Сплин
# Воплі Відоплясова event page found in cache..No concerts from  Воплі Відоплясова
# Голос Омерики event page found in cache..Done with  Голос Омерики
# Борис Гребенщиков event page found in cache..Done with  Борис Гребенщиков
# Чайф event page found in cache..No concerts from  Чайф
# 7Б event page found in cache..No concerts from  7Б
# Мёртвые Дельфины event page found in cache..No concerts from  Мёртвые Дельфины
# Wynton Marsalis event page found in cache..No concerts from  Wynton Marsalis
# David Bowie event page found in cache..No concerts from  David Bowie
# Потомучто event page found in cache..No concerts from  Потомучто
#
#  Мураками
#   Мураками-in-2022-07-14
#     eventartist : Мураками
#     eventtime : 2022-07-14
#     eventvenue : Улетай поле
#     eventcity : село Лагуново
#     eventcountry : Russian Federation
# Briqueville
#   Briqueville-in-2021-10-01
#     eventartist : Briqueville
#     eventtime : 2021-10-01
#     eventvenue : Muziekcentrum TRIX
#     eventcity : Antwerpen
#     eventcountry : Belgium
#   Briqueville-in-2021-11-02
#     eventartist : Briqueville
#     eventtime : 2021-11-02
#     eventvenue : Balzaal Vooruit
#     eventcity : Gent
#     eventcountry : Belgium
#   Briqueville-in-2022-08-17
#     eventartist : Briqueville
#     eventtime : 2022-08-17
#     eventvenue : Fernhill Farm
#     eventcity : Compton Martin
#     eventcountry : United Kingdom
# Сплин
#   Сплин-in-2021-11-27
#     eventartist : Сплин
#     eventtime : 2021-11-27
#     eventvenue : Music Media Dome
#     eventcity : Moscow
#     eventcountry : Russian Federation
#   Сплин-in-2022-07-14
#     eventartist : Сплин
#     eventtime : 2022-07-14
#     eventvenue : Улетай поле
#     eventcity : село Лагуново
#     eventcountry : Russian Federation
# Голос Омерики
#   Голос Омерики-in-2021-10-28
#     eventartist : Голос Омерики
#     eventtime : 2021-10-28
#     eventvenue : ЦКЗ Аврора
#     eventcity : Санкт-Петербург
#     eventcountry : Russian Federation
# Борис Гребенщиков
#   Борис Гребенщиков-in-2021-10-04
#     eventartist : Борис Гребенщиков
#     eventtime : 2021-10-04
#     eventvenue : ATTA Centre
#     eventcity : Rīga
#     eventcountry : Latvia

# %%
import GreatGigBotLib

lastfmUser='Anastasia20009'
hoursDelta = 100
minListens = 3

events = GreatGigBotLib.getLastfmEvents(lastfmUser,hoursDelta,minListens)
GreatGigBotLib.prettyThree(events)
# Out:
# Library ivanshello_page_1 found in cache..Parsed
# Library ivanshello_page_2 found in cache..Parsed. timeDelay reached
# Parsed
#
# provedArtistList:
#  ['Людмила Гурченко', 'Briqueville']
# Artist proved: 2
#
# Людмила Гурченко event page found in cache..No concerts from  Людмила Гурченко
# Briqueville event page found in cache..Done with  Briqueville
#
#  Briqueville
#   Briqueville-in-2021-10-01
#     eventartist : Briqueville
#     eventtime : 2021-10-01
#     eventvenue : Muziekcentrum TRIX
#     eventcity : Antwerpen
#     eventcountry : Belgium
#   Briqueville-in-2021-11-02
#     eventartist : Briqueville
#     eventtime : 2021-11-02
#     eventvenue : Balzaal Vooruit
#     eventcity : Gent
#     eventcountry : Belgium
#   Briqueville-in-2022-08-17
#     eventartist : Briqueville
#     eventtime : 2022-08-17
#     eventvenue : Fernhill Farm
#     eventcity : Compton Martin
#     eventcountry : United Kingdom
#
# %D0%92%D0%98%D0%90%20%C2%AB%D0%92%D0%BE%D0%BB%D0%B3%D0%B0-%D0%92%D0%BE%D0%BB%D0%B3%D0%B0%C2%BB
# Downloading Anastasia20009_page_1 library page...Done
# Parsed
# Downloading Anastasia20009_page_2 library page...Done
# Parsed
# Downloading Anastasia20009_page_3 library page...Done
# Parsed
# Downloading Anastasia20009_page_4 library page...Done
# Parsed
# Downloading Anastasia20009_page_5 library page...Done
# Parsed. timeDelay reached
# Parsed
#
# provedArtistList:
#  ['Arca', 'Ляпис Трубецкой', 'Corpse', 'Shortparis', 'Ghostemane', 'Chet Faker', 'Тима Белорусских', 'Hollywood Undead', 'INSTASAMKA', 'Michaela Laws', 'Placebo', 'Nautilus Pompilius', 'Morgenshtern', 'Комиссар', 'Halsey', 'Chills', 'Måneskin']
# Artist proved: 17
#
# Downloading Arca event page...Done
# Done with  Arca
# Downloading Ляпис Трубецкой event page...Done
# No concerts from  Ляпис Трубецкой
# Downloading Corpse event page...Done
# No concerts from  Corpse
# Downloading Shortparis event page...Done
# Done with  Shortparis
# Downloading Ghostemane event page...Done
# Done with  Ghostemane
# Downloading Chet Faker event page...Done
# Done with  Chet Faker
# Downloading Тима Белорусских event page...Done
# Done with  Тима Белорусских
# Downloading Hollywood Undead event page...Done
# No concerts from  Hollywood Undead
# Downloading INSTASAMKA event page...Done
# No concerts from  INSTASAMKA
# Downloading Michaela Laws event page...Done
# No concerts from  Michaela Laws
# Downloading Placebo event page...Done
# Done with  Placebo
# Downloading Nautilus Pompilius event page...Done
# No concerts from  Nautilus Pompilius
# Downloading Morgenshtern event page...Done
# Done with  Morgenshtern
# Downloading Комиссар event page...Done
# No concerts from  Комиссар
# Downloading Halsey event page...Done
# No concerts from  Halsey
# Downloading Chills event page...Done
# No concerts from  Chills
# Downloading Måneskin event page...Done
# Done with  Måneskin
#
#  Arca
#   Arca-in-2022-06-16
#     eventartist : Arca
#     eventtime : 2022-06-16
#     eventvenue : Fira de Barcelona - Gran Via
#     eventcity : L&#39;Hospitalet de Llobregat
#     eventcountry : Spain
# Shortparis
#   Shortparis-in-2021-12-04
#     eventartist : Shortparis
#     eventtime : 2021-12-04
#     eventvenue : Main Stage
#     eventcity : Moscow
#     eventcountry : Russian Federation
#   Shortparis-in-2021-11-05
#     eventartist : Shortparis
#     eventtime : 2021-11-05
#     eventvenue : BACKSTAGE
#     eventcity : Тула
#     eventcountry : Russian Federation
#   Shortparis-in-2021-12-11
#     eventartist : Shortparis
#     eventtime : 2021-12-11
#     eventvenue : Сибур Арена
#     eventcity : Saint Petersburg
#     eventcountry : Russian Federation
#   Shortparis-in-2022-06-04
#     eventartist : Shortparis
#     eventtime : 2022-06-04
#     eventvenue : Лужники
#     eventcity : Москва
#     eventcountry : Russian Federation
#   Shortparis-in-2022-09-13
#     eventartist : Shortparis
#     eventtime : 2022-09-13
#     eventvenue : Proxima
#     eventcity : Warszawa
#     eventcountry : Poland
#   Shortparis-in-2022-09-24
#     eventartist : Shortparis
#     eventtime : 2022-09-24
#     eventvenue : Botanique
#     eventcity : Brussels
#     eventcountry : Belgium
# Ghostemane
#   Ghostemane-in-2021-09-29
#     eventartist : Ghostemane
#     eventtime : 2021-09-29
#     eventvenue : ГЛАВCLUB GREEN CONCERT
#     eventcity : г. Москва
#     eventcountry : Russian Federation
#   Ghostemane-in-2021-09-26
#     eventartist : Ghostemane
#     eventtime : 2021-09-26
#     eventvenue : Klub Studio
#     eventcity : Kraków
#     eventcountry : Poland
#   Ghostemane-in-2021-09-28
#     eventartist : Ghostemane
#     eventtime : 2021-09-28
#     eventvenue : Клуб-фестиваль «МОРЗЕ»
#     eventcity : Санкт-Петербург
#     eventcountry : Russian Federation
#   Ghostemane-in-2021-10-05
#     eventartist : Ghostemane
#     eventtime : 2021-10-05
#     eventvenue : Звезда
#     eventcity : Г.Самара
#     eventcountry : Russian Federation
#   Ghostemane-in-2021-10-08
#     eventartist : Ghostemane
#     eventtime : 2021-10-08
#     eventvenue : Tele-Club
#     eventcity : Екатеринбург
#     eventcountry : Russian Federation
#   Ghostemane-in-2021-10-10
#     eventartist : Ghostemane
#     eventtime : 2021-10-10
#     eventvenue : Лофт-парк «Подземка»
#     eventcity : Новосибирск
#     eventcountry : Russian Federation
#   Ghostemane-in-2021-11-13
#     eventartist : Ghostemane
#     eventtime : 2021-11-13
#     eventvenue : Cineteatro Capitólio
#     eventcity : Lisboa
#     eventcountry : Portugal
#   Ghostemane-in-2021-11-14
#     eventartist : Ghostemane
#     eventtime : 2021-11-14
#     eventvenue : Sala Cats
#     eventcity : Madrid
#     eventcountry : Spain
#   Ghostemane-in-2021-11-16
#     eventartist : Ghostemane
#     eventtime : 2021-11-16
#     eventvenue : La Madeleine
#     eventcity : Bruxelles
#     eventcountry : Belgium
#   Ghostemane-in-2021-11-18
#     eventartist : Ghostemane
#     eventtime : 2021-11-18
#     eventvenue : E-Werk
#     eventcity : Cologne
#     eventcountry : Germany
#   Ghostemane-in-2021-11-23
#     eventartist : Ghostemane
#     eventtime : 2021-11-23
#     eventvenue : Progresja
#     eventcity : Warszawa
#     eventcountry : Poland
#   Ghostemane-in-2021-11-24
#     eventartist : Ghostemane
#     eventtime : 2021-11-24
#     eventvenue : B90
#     eventcity : Gdańsk
#     eventcountry : Poland
#   Ghostemane-in-2021-11-27
#     eventartist : Ghostemane
#     eventtime : 2021-11-27
#     eventvenue : Forum Karlín
#     eventcity : Praha
#     eventcountry : Czech Republic
#   Ghostemane-in-2021-11-28
#     eventartist : Ghostemane
#     eventtime : 2021-11-28
#     eventvenue : Arena Wien
#     eventcity : Vienna
#     eventcountry : Austria
#   Ghostemane-in-2021-12-02
#     eventartist : Ghostemane
#     eventtime : 2021-12-02
#     eventvenue : Magazzini Generali
#     eventcity : Milano
#     eventcountry : Italy
#   Ghostemane-in-2021-12-03
#     eventartist : Ghostemane
#     eventtime : 2021-12-03
#     eventvenue : Magazzini Generali
#     eventcity : Milano
#     eventcountry : Italy
#   Ghostemane-in-2021-12-05
#     eventartist : Ghostemane
#     eventtime : 2021-12-05
#     eventvenue : TonHalle
#     eventcity : Munich
#     eventcountry : Germany
#   Ghostemane-in-2021-12-06
#     eventartist : Ghostemane
#     eventtime : 2021-12-06
#     eventvenue : X-tra
#     eventcity : Zürich
#     eventcountry : Switzerland
#   Ghostemane-in-2021-12-08
#     eventartist : Ghostemane
#     eventtime : 2021-12-08
#     eventvenue : Bataclan
#     eventcity : Paris
#     eventcountry : France
#   Ghostemane-in-2021-12-11
#     eventartist : Ghostemane
#     eventtime : 2021-12-11
#     eventvenue : O2 Ritz
#     eventcity : Manchester
#     eventcountry : United Kingdom
#   Ghostemane-in-2022-06-17
#     eventartist : Ghostemane
#     eventtime : 2022-06-17
#     eventvenue : Val de Moine
#     eventcity : Clisson
#     eventcountry : France
# Chet Faker
#   Chet Faker-in-2021-10-01
#     eventartist : Chet Faker
#     eventtime : 2021-10-01
#     eventvenue : Zilker Park
#     eventcity : Austin
#     eventcountry : United States
#   Chet Faker-in-2021-11-12
#     eventartist : Chet Faker
#     eventtime : 2021-11-12
#     eventvenue : Parque Fundidora
#     eventcity : Estacionamiento Sta. Catarina (Mexico)
#     eventcountry : Mexico
#   Chet Faker-in-2022-03-29
#     eventartist : Chet Faker
#     eventtime : 2022-03-29
#     eventvenue : House of Blues
#     eventcity : Boston
#     eventcountry : United States
# Тима Белорусских
#   Тима Белорусских-in-2021-11-12
#     eventartist : Тима Белорусских
#     eventtime : 2021-11-12
#     eventvenue : Лофт-парк «Подземка»
#     eventcity : Новосибирск
#     eventcountry : Russian Federation
# Placebo
#   Placebo-in-2022-06-16
#     eventartist : Placebo
#     eventtime : 2022-06-16
#     eventvenue : Парк Лужники
#     eventcity : Moscow
#     eventcountry : Russian Federation
#   Placebo-in-2022-06-25
#     eventartist : Placebo
#     eventtime : 2022-06-25
#     eventvenue : Werchter
#     eventcity : Werchter
#     eventcountry : Belgium
#   Placebo-in-2022-06-27
#     eventartist : Placebo
#     eventtime : 2022-06-27
#     eventvenue : Šalata
#     eventcity : Zagreb
#     eventcountry : Croatia
#   Placebo-in-2022-07-06
#     eventartist : Placebo
#     eventtime : 2022-07-06
#     eventvenue : Національний виставковий центр (ВДНГ)
#     eventcity : Kyiv
#     eventcountry : Ukraine
#   Placebo-in-2022-08-25
#     eventartist : Placebo
#     eventtime : 2022-08-25
#     eventvenue : Vilar de Mouros
#     eventcity : Vilar de Mouros
#     eventcountry : Portugal
# Morgenshtern
#   Morgenshtern-in-2022-07-22
#     eventartist : Morgenshtern
#     eventtime : 2022-07-22
#     eventvenue : Усадьба Отрада
#     eventcity : с. Волковское
#     eventcountry : Russian Federation
# Måneskin
#   Måneskin-in-2021-12-15
#     eventartist : Måneskin
#     eventtime : 2021-12-15
#     eventvenue : Palazzo dello Sport
#     eventcity : Roma
#     eventcountry : Italy
#   Måneskin-in-2021-12-18
#     eventartist : Måneskin
#     eventtime : 2021-12-18
#     eventvenue : Mediolanum Forum
#     eventcity : Assago
#     eventcountry : Milano
#   Måneskin-in-2022-03-20
#     eventartist : Måneskin
#     eventtime : 2022-03-20
#     eventvenue : Unipol Arena
#     eventcity : Casalecchio di Reno (BO)
#     eventcountry : Italy
#   Måneskin-in-2022-03-22
#     eventartist : Måneskin
#     eventtime : 2022-03-22
#     eventvenue : Mediolanum Forum
#     eventcity : Assago
#     eventcountry : Milano
#   Måneskin-in-2022-04-03
#     eventartist : Måneskin
#     eventtime : 2022-04-03
#     eventvenue : Pala Alpitour (ex Palaolimpico)
#     eventcity : Torino
#     eventcountry : Italy
#   Måneskin-in-2022-06-03
#     eventartist : Måneskin
#     eventtime : 2022-06-03
#     eventvenue : Zeppelinfeld
#     eventcity : Nuremberg
#     eventcountry : Germany
#   Måneskin-in-2022-06-23
#     eventartist : Måneskin
#     eventtime : 2022-06-23
#     eventvenue : Ekeberg
#     eventcity : Oslo
#     eventcountry : Norway
#   Måneskin-in-2022-07-09
#     eventartist : Måneskin
#     eventtime : 2022-07-09
#     eventvenue : Circo Massimo
#     eventcity : Roma
#     eventcountry : Italy

# %%
eventArtist = '«W » '
lastfmEventUrl = urllib.parse.quote(eventArtist,safe="»«")
print(lastfmEventUrl)
# Out:
# %C2%ABW%20%C2%BB%20
